# %%
import influxdb_client, os, time
from influxdb_client import InfluxDBClient, Point, WritePrecision
from queryDSL import InfluxQueryBuilder, QueryAggregation, QueryFilter
import requests
import json

# %%
token = "NVRAh0Hy9gLvSJVlIaYVRIP5MTktlqBHCOGxpgzIOHdSD-fu2vGjug5NmMcTv2QvH7BK6XG0tQvaoPXUWmuvLQ=="
org = "Realtime"
url = "http://localhost:8086"
cacheUrlRaw = "http://127.0.0.1:5000/api/queryRaw"
cacheUrlJson = "http://127.0.0.1:5000/api/query"
resetUrl = "http://127.0.0.1:5000/api/reset"
client = influxdb_client.InfluxDBClient(url=url, token=token, org=org)

query_api = client.query_api()

# %%
query3Builder = (InfluxQueryBuilder()
             .withBucket("Test")
             .withFilter(QueryFilter("_measurement", "cpu_usage"))
             .withFilter(QueryFilter("_field", "value"))
             .withFilter(QueryFilter("platform", "mac_os").OR(QueryFilter("platform", "windows")))
             .withAggregate(QueryAggregation("1m", "mean", False))
             .withRelativeRange('840m', None)
             .withYield("mean")
    )

query4Builder = (InfluxQueryBuilder()
              .withBucket("Test")
              .withFilter(QueryFilter("_measurement", "cpu_usage"))
              .withFilter(QueryFilter("_field", "value"))
              .withFilter(QueryFilter("platform", "mac_os").OR(QueryFilter("platform", "windows")))
              .withAggregate(QueryAggregation("1m", "mean", False))
              .withRelativeRange('840m', None)
              .withYield("median")
      )

query3 = query3Builder.buildFluxStr()
query4 = query4Builder.buildFluxStr()
query3Json = query3Builder.buildJson()
query4Json = query4Builder.buildJson()

# %%
# Test runtime speed of queries against Cache for partial cache hits

runs = 20
delay = 1
without = []
cached = []
requests.post(resetUrl)
for i in range(runs):
   #queryMedian
   start = time.time()
   query4Str = InfluxQueryBuilder.fromJson(query4Json).buildFluxStr()
   tables2 = query_api.query(query4Str, org="Realtime").to_json()
   elapsed = time.time() - start
   without.append(elapsed)
   #cachedJson
   query4Json = query4Builder.buildJson()
   start = time.time()
   result = requests.post(cacheUrlJson, json=query4Json).text
   elapsed = time.time() - start
   cached.append(elapsed)
   time.sleep(delay)

# %%
#Performance results
print("Without cache: avg", sum(without)/len(without), "seconds")
print("With cache: avg", sum(cached)/len(cached), "seconds")
import matplotlib.pyplot as plt

# Performance results

plt.plot(without, label='Without Cache')
plt.plot(cached, label='With Cache')
plt.xlabel('Iteration')
plt.ylabel('Time (seconds)')
plt.title('Performance Comparison - Median')
plt.legend()
plt.show()
# Out:
# Without cache: avg 0.11309846639633178 seconds
# With cache: avg 0.0361713171005249 seconds

# %%
# Test runtime speed of queries against Cache for partial cache hits

runs = 20
delay = 1
withoutMean = []
cachedMean = []
requests.post(resetUrl)
for i in range(runs):
   #queryMedian
   start = time.time()
   query3Str = InfluxQueryBuilder.fromJson(query3Json).buildFluxStr()
   tables2 = query_api.query(query3Str, org="Realtime").to_json()
   elapsed = time.time() - start
   withoutMean.append(elapsed)
   #cachedJson
   query3Json = query3Builder.buildJson()
   start = time.time()
   result = requests.post(cacheUrlJson, json=query3Json).text
   elapsed = time.time() - start
   cachedMean.append(elapsed)
   time.sleep(delay)

# %%
#Performance results
print("Without cache: avg", sum(withoutMean)/len(withoutMean), "seconds")
print("With cache: avg", sum(cachedMean)/len(cachedMean), "seconds")
import matplotlib.pyplot as plt

# Performance results

plt.plot(withoutMean, label='Without Cache')
plt.plot(cachedMean, label='With Cache')
plt.xlabel('Iteration')
plt.ylabel('Time (seconds)')
plt.title('Performance Comparison - Mean')
plt.legend()
plt.show()
# Out:
# Without cache: avg 0.02177032232284546 seconds
# With cache: avg 0.01611102819442749 seconds

# %%
maxQueryBuilder = (InfluxQueryBuilder()
             .withBucket("Test")
             .withFilter(QueryFilter("_measurement", "cpu_usage"))
             .withFilter(QueryFilter("_field", "value"))
             .withFilter(QueryFilter("platform", "mac_os").OR(QueryFilter("platform", "windows")))
             .withAggregate(QueryAggregation("10m", "max", False))
             .withRelativeRange('840m', None)
             .withYield("max")
    )

maxQueryStr = maxQueryBuilder.buildFluxStr()
maxQueryJson = maxQueryBuilder.buildJson()

# %%
# Test runtime speed of queries against Cache for partial cache hits

runs = 20
delay = 1
withoutMax = []
cachedMax = []
requests.post(resetUrl)
for i in range(runs):
   #queryMedian
   start = time.time()
   maxQueryStr = InfluxQueryBuilder.fromJson(maxQueryJson).buildFluxStr()
   tables2 = query_api.query(maxQueryStr, org="Realtime").to_json()
   elapsed = time.time() - start
   withoutMax.append(elapsed)
   #cachedJson
   maxQueryJson = maxQueryBuilder.buildJson()
   start = time.time()
   result = requests.post(cacheUrlJson, json=maxQueryJson).text
   elapsed = time.time() - start
   cachedMax.append(elapsed)
   time.sleep(delay)

# %%
#Performance results
print("Without cache: avg", sum(withoutMax)/len(withoutMax), "seconds")
print("With cache: avg", sum(cachedMax)/len(cachedMax), "seconds")
import matplotlib.pyplot as plt

# Performance results

plt.plot(withoutMax, label='Without Cache')
plt.plot(cachedMean, label='With Cache')
plt.xlabel('Iteration')
plt.ylabel('Time (seconds)')
plt.title('Performance Comparison - Max')
plt.legend()
plt.show()
# Out:
# Without cache: avg 0.025731432437896728 seconds
# With cache: avg 0.018086934089660646 seconds

# %%
#Correctness test
query5Builder = (InfluxQueryBuilder()
              .withBucket("Test")
              .withFilter(QueryFilter("_measurement", "cpu_usage"))
              .withFilter(QueryFilter("_field", "value"))
              .withFilter(QueryFilter("platform", "mac_os").OR(QueryFilter("platform", "windows")))
              .withAggregate(QueryAggregation("1m", "mean", False))
              .withRelativeRange('75m', '15m')
              .withYield("median")
      )

query6Builder = (InfluxQueryBuilder()
              .withBucket("Test")
              .withFilter(QueryFilter("_measurement", "cpu_usage"))
              .withFilter(QueryFilter("_field", "value"))
              .withFilter(QueryFilter("platform", "mac_os").OR(QueryFilter("platform", "windows")))
              .withAggregate(QueryAggregation("1m", "mean", False))
              .withRelativeRange('65m', '5m')
              .withYield("median")
      )

query5Json = query5Builder.buildJson()
query6Json = query6Builder.buildJson()
query5Str = query5Builder.buildFluxStr()
query6Str = query6Builder.buildFluxStr()

# %%
reset = requests.post(resetUrl)
influxDBResult = json.loads(query_api.query(query6Str, org="Realtime").to_json())
cacheStore = requests.post(cacheUrlJson, json=query5Json)
time.sleep(2)
cacheResult = requests.post(cacheUrlJson, json=query6Json).json()

print(query6Json)
print(query6Str)
print(len(influxDBResult))
print(len(cacheResult))
# Out:
# {'bucket': 'Test', 'range': {'start': 1710256116, 'end': 1710259716}, 'filters': [{'key': '_measurement', 'value': 'cpu_usage', 'type': 'raw'}, {'key': '_field', 'value': 'value', 'type': 'raw'}, {'filter': [{'key': 'platform', 'value': 'mac_os', 'type': 'raw'}, {'key': 'platform', 'value': 'windows', 'type': 'raw'}], 'type': 'or'}], 'yield': 'median', 'aggregate': {'timeWindow': '1m', 'aggFunc': 'mean', 'createEmpty': False}}
# from(bucket: "Test")
# |> range(start: 1710256116, stop: 1710259716)
# |> filter(fn: (r) => r["_measurement"] == "cpu_usage")
# |> filter(fn: (r) => r["_field"] == "value")
# |> filter(fn: (r) => r["platform"] == "mac_os" or r["platform"] == "windows")
# |> aggregateWindow(every: 1m, fn: mean, createEmpty: false)
# |> yield(name: "median")
# 122
# 124

# %%
from matplotlib import pyplot as plt
import numpy as np

def extractPlots(json):
    result = dict()
    curTable = 0
    for item in json:
        platform = item["platform"]
        value = item["_value"]
        time = item["_time"]
        if platform not in result:
            result[platform] = dict()
            result[platform]["time"] = []
            result[platform]["value"] = []
        result[platform]["time"].append(time)
        result[platform]["value"].append(value)
    return result

influxArrs = extractPlots(influxDBResult)
cacheArrs = extractPlots(cacheResult)

# %%
import matplotlib.pyplot as plt

# Plotting cacheArrs
import matplotlib.pyplot as plt

# Create subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Plotting influxArrs
for platform, data in influxArrs.items():
    ax1.plot(data['time'], data['value'], label=f'influxArrs - {platform}')

# Set title and labels for influxArrs subplot
ax1.set_title('influxArrs')
ax1.set_xlabel('Time')
ax1.set_ylabel('Value')
ax1.legend()

# Plotting cacheArrs
for platform, data in cacheArrs.items():
    ax2.plot(data['time'], data['value'], label=f'cacheArrs - {platform}')

# Set title and labels for cacheArrs subplot
ax2.set_title('cacheArrs')
ax2.set_xlabel('Time')
ax2.set_ylabel('Value')
ax2.legend()

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()
